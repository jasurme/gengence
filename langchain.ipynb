# %%
from messages import Message, Messages
from gemini import Gemini
       

messages = []
messages.append(Message(1, "you are lionel messi who speak in eng"))

# gemini = Gemini(model="gemini-2.0-flash")
# messages.append(Message(2, 'whoa are you'))
# ai = gemini.generate(messages)
# print(ai)
message_bank = Messages('a')
message_bank.add(message1='ai')
# Out:
# initialized messages db
# successfully added

# %%
message_bank.add("Message(1, 'you are messi')")
# Out:
# successfully added

# %%
import os
import sqlite3
os.makedirs('message_bank', exist_ok=True)
conn = sqlite3.connect("message_bank/messages.db")
c = conn.cursor()
c.execute("CREATE TABLE IF NOT EXISTS messages (message TEXT)")
c.execute("select * from messages")
rows = c.fetchall()
print('successfully got all messages in db')
conn.close()
print(rows)
# Out:
# successfully got all messages in db
# [('<system_message intent=you are helpful assistant>you are lionel messi who speak in english and answers with 2 max sentences</system_message>',)]

# %%
ms = "a"
ms+=" " "r"
ms
# Out:
# 'a r'
